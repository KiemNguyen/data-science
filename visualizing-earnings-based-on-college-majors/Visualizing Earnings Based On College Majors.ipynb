# %% [markdown]
# ## 1. Read the data

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
recent_grads = pd.read_csv("recent-grads.csv")

# %%
recent_grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# Low_wage_jobs                             193
# Name: 0, dtype: object

# %% [markdown]
# ## 2. Pandas, Scatter Plots

# %%
recent_grads.plot(x='Sample_size', y='Median', kind='scatter', title='Sample_size and Median')

# %%
recent_grads.plot(x='Sample_size',y='Unemployment_rate', kind='scatter', title='Sample_size and Unemployment_rate')

# %%
recent_grads.plot(x='Full_time', y='Median', kind='scatter', title='Full_time and Median')

# %%
recent_grads.plot(x='ShareWomen', y='Unemployment_rate', kind='scatter', title='ShareWomen and Unemployment_rate')

# %%
recent_grads.plot(x='Men', y='Median', kind='scatter', title='Men and Median')

# %%
recent_grads.plot(x='Women', y='Median', kind='scatter', title='Women and Median')

# %% [markdown]
# ## 3. Pandas, Histograms

# %%
recent_grads['Sample_size'].hist(bins=25, range=(0,5000))

# %%
recent_grads['Median'].hist(bins=25, range=(0,100000))

# %%
recent_grads['Employed'].hist(bins=25, range=(0,5000))

# %%
recent_grads['Full_time'].hist(bins=25, range=(0,5000))

# %%
recent_grads['ShareWomen'].hist(bins=25, range=(0,1))

# %%
recent_grads['Unemployment_rate'].hist(bins=25, range=(0,1))

# %%
recent_grads['Men'].hist(bins=25, range=(0,5000))

# %%
recent_grads['Women'].hist(bins=25, range=(0,5000))

# %% [markdown]
# ## 4. Pandas, Scatter Matrix Plot

# %%
from pandas.tools.plotting import scatter_matrix

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median']])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11c30eef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c372c50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11c4fb198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c54c898>]], dtype=object)

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median', 'Unemployment_rate']])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11c63c198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c6a1518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c7f77f0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11c84bdd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c8bc128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c8bc160>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11c93b630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c990e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11ca00128>]], dtype=object)

# %% [markdown]
# ## 5. Pandas, Bar Plots

# %% [markdown]
# Compare the percentages of women (ShareWomen) from the 10 highest paying majors and from the 10 lowest paying majors.

# %%
recent_grads[:10].plot.bar(x='Major', y='ShareWomen')

# %%
recent_grads[163:].plot.bar(x='Major', y='ShareWomen')

# %% [markdown]
# Compare the unemployment rate (Unemployment_rate) from the 10 highest paying majors and from the 10 lowest paying majors.

# %%
recent_grads[:10].plot.bar(x='Major', y='Unemployment_rate')

# %%
recent_grads[163:].plot.bar(x='Major', y='Unemployment_rate')
